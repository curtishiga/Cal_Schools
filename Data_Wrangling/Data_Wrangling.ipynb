# %%
import pyforest

# %%
school = pd.read_csv('..\Data\California_School_Demographics.csv')

# %%
school.head()
# Out:
#             X          Y  OBJECTID     Year         FedID       CDSCode  \
# 0 -121.590439  39.153060     10001  2018-19  6.072601e+10  5.872729e+13
# 1 -121.549427  39.119801     10002  2018-19  6.240901e+10  5.872736e+13
# 2 -121.580742  39.153893     10003  2018-19  6.240901e+10  5.872736e+13
# 3 -121.587390  39.156443     10004  2018-19  6.240901e+10  5.872736e+13
# 4 -121.538152  39.083408     10005  2018-19  6.240900e+10  5.872737e+13
#
#       CDCode CountyName              DistrictName                  SchoolName  \
# 0  5872728.0       Yuba   Camptonville Elementary                CORE Charter
# 1  5872736.0       Yuba  Marysville Joint Unified        Edgewater Elementary
# 2  5872736.0       Yuba  Marysville Joint Unified  Paragon Collegiate Academy
# 3  5872736.0       Yuba  Marysville Joint Unified    Marysville Community Day
# 4  5872736.0       Yuba  Marysville Joint Unified              Lindhurst High
#
# ...

# %%
school.describe()
# Out:
#                   X             Y      OBJECTID         FedID       CDSCode  \
# count  10033.000000  10033.000000  10033.000000  1.003200e+04  1.003200e+04
# mean    -119.592181     35.822549   5017.000000  6.243843e+10  2.923451e+13
# std        2.019892      2.208862   2896.421959  1.830033e+09  1.406465e+13
# min     -124.284893     32.547895      1.000000  6.000010e+10  1.100170e+12
# 25%     -121.596608     33.964054   2509.000000  6.118500e+10  1.964733e+13
# 50%     -119.049831     34.927985   5017.000000  6.227101e+10  3.066648e+13
# 75%     -117.945675     37.753454   7525.000000  6.338600e+10  3.773791e+13
# max     -114.395807     41.989053  10033.000000  6.911371e+10  5.872770e+13
#
#              CDCode      Latitude     Longitude        CongUS      SenateCA  \
# count  1.003200e+04  10032.000000  10032.000000  10031.000000  10031.000000
# mean   2.923451e+06     35.822354   -119.592228     24.579304     18.691157
# ...

# %%
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10033 entries, 0 to 10032
# Data columns (total 88 columns):
# X                    10033 non-null float64
# Y                    10033 non-null float64
# OBJECTID             10033 non-null int64
# Year                 10032 non-null object
# FedID                10032 non-null float64
# CDSCode              10032 non-null float64
# CDCode               10032 non-null float64
# CountyName           10032 non-null object
# DistrictName         10032 non-null object
# SchoolName           10032 non-null object
# SchoolType           10032 non-null object
# EduOption            10032 non-null object
# Status               10032 non-null object
# OpenDate             10032 non-null object
# ClosedDate           104 non-null object
# SchoolLevel          10032 non-null object
# GradeLow             10032 non-null object
# GradeHigh            10029 non-null object
# Charter              10032 non-null object
# ...

# %%
# Drop Street, CDCode
school.drop(['Street', 'CDCode'], axis=1)

# %%
# Remove Charter Schools (Charter == N), CharterNum(?), FundingType

# %%
# ClosedDate remove

# %%
# Remove Virtual?

# %%
# Investigate CongUS, AssemblyCA, SenateCA with Zillow data

# %%
# investigate SchoolLevel, GradeLow, GradeHigh, SchoolType, EduOptions, LocSource

# %%
# County vs CountyGeo

# %%
# Investigate TitleIStatus, Title I funding

# %%
# Dashboard Alternative School Status (DASS)?
